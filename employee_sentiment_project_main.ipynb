# %% [markdown]
# # Employee Sentiment Analysis
#
# This notebook demonstrates the pipeline for labeling sentiment using **TextBlob**, performing EDA, computing monthly scores, ranking employees, detecting flight risk, and training a simple linear regression model.
#
# Files included:
# - `test.csv` (input)
# - `sentiment_analysis.py` (main pipeline)
# - `annotated_messages.csv`, `monthly_scores.csv`, `features_for_model.csv` (generated outputs)
#
# Run the cells below to execute the pipeline.

# %%
# !python3 sentiment_analysis.py test.csv

# Show generated files
import pandas as pd
from pathlib import Path
p = Path('annotated_messages.csv')
print('annotated_messages.csv exists:', p.exists())
if p.exists():
    display(pd.read_csv(p).head())

p2 = Path('monthly_scores.csv')
print('monthly_scores.csv exists:', p2.exists())
if p2.exists():
    display(pd.read_csv(p2).head())

p3 = Path('features_for_model.csv')
print('features_for_model.csv exists:', p3.exists())
if p3.exists():
    display(pd.read_csv(p3).head())
